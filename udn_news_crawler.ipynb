# %%
import requests
from bs4 import BeautifulSoup
import time
import json

headers= {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36",
    "referer": "https://www.google.com/"
}

# %%
url = "https://udn.com/api/more?page={}&id=&channelId=1&cate_id=0&type=breaknews&totalRecNo=11708"
# 535    2020 last page


all_news = []
for page in range(0,534):
    print("Page" , page)
    
    try:
        res = requests.get(url = url.format(page), headers = headers).json()
        #news_json = json.loads(res.text)

        for news in res["lists"]:
            news_dict = {}
            news_link = "https://udn.com" + news["titleLink"]
            news_title = news["title"]
            news_date = news["time"]["date"]
            if news_title in list(df["news_title"]):
                pass            

            news_dict["news_title"] = news_title
            news_dict["news_date"] = news_date
            news_dict["news_link"] = news_link
            print(news_title)
            print(news_link)
            #print(news_date)

            news_res = requests.get(url = news_link, headers=headers)
            news_soup = BeautifulSoup(news_res.text, "html.parser")
            article_list = news_soup.select("div[class='article-content__paragraph']")
            article = article_list[0].text

            news_dict["news_article"] = article
            #print(article)

            all_news.append(news_dict)
    except IndexError:
        pass
    except JSONDecodeError:
        pass
        
    time.sleep(30)

# %%
import pandas as pd

df = pd.DataFrame(all_news)

# %%
df
# Out:
#                                    news_title         news_date  \
# 0                  台南人第一次到新竹有何感覺？ 網曝一差異「先自備糖」  2020-06-01 18:20
# 1                     男子為結婚苦存8年錢買房 女友爸：房太小不准！  2020-06-01 17:13
# 2     【閱讀沙龍Online】#13 紀實漫畫《來自清水的孩子》：游珮芸V.S周見信  2020-06-01 17:11
# 3                  全家新甜點咬一口瞬間爆漿 心得文曝光網友直呼：超生火  2020-06-01 16:36
# 4                  雞排店收「詭異50元硬幣」 網喊賺到：比真的貴數十倍  2020-06-01 16:27
# ...                                       ...               ...
# 1031              挺過228 、白恐、美麗島 陳澄波家屬藏友人畫作有洋蔥  2019-12-29 11:47
# 1032                 拿破崙終身執政證書寄存國圖 學者提兩點觀察辨真偽  2019-12-28 19:00
# 1033         「鄭成功」神展開！17世紀海賊王變啤酒代言人　讓歷史走入生活記憶  2019-12-28 10:00
# 1034                   明年起 國考11項新措施  高普考變革看這裡  2019-12-27 21:49
# 1035      影／【唐綺陽】2020上半年12星座運勢出爐！感情、工作、健康運一次看  2019-12-27 13:06
#
#                                               news_link  \
# 0     https://udn.com/news/story/120913/4605664?from...
# 1     https://udn.com/news/story/7272/4605626?from=u...
# ...
